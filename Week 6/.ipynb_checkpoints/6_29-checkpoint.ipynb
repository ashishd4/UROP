# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
x = []
y = []

plots = 200

for i in range(plots):
    x.append(i + 1)
    y.append(np.sin(x[-1]/plots * 2 * np.pi))

plt.plot(x, y, color = 'orangered')
plt.title('Initial Velocity Field')
plt.ylabel('Velocity (m/s)')
plt.xlabel('X Position (m)')
plt.xlim(x[0], x[-1])
plt.grid()
plt.show()

# %%
y_avgs = []

for i in range(plots):
    y_avgs.append(y[i])

boxes = 40
box_size = len(x)/boxes
temp = 0

for i in range(boxes):
    temp = 0
    
    for j in range(int(box_size)):
        temp += y_avgs[int(i*box_size + j)]
    temp /= box_size
    
    for j in range(int(box_size)):
        y_avgs[int(i*box_size + j)] = temp

# %%
plt.plot(x, y_avgs, color = 'navy') #, label = 'Approximation'
#  plt.plot(x, y, color = 'orangered', label = 'True Initial Value')
plt.title('Approximation of Initial Velocity Field')
plt.ylabel('Velocity (m/s)')
plt.xlabel('X Position (m)')
plt.xlim(x[0], x[-1])
# plt.legend(frameon=False)
plt.grid()
plt.show()

# %%
def flux_function(uL, uR):
    return 0.5*(uL + uR)

# %%
def godunov(wL, wR):
    # Burger's equation
    fL = wL**2 / 2
    fR = wR**2 / 2
    
    f = max(fL, fR)
    
    if (wL < wR):
        f = min(fL, fR)
    
    if (wL < 0 and wR > 0):
        f = 0
        
    return f

# %%
def flux_approx_method(steps):
    dt = 0.1 #s, arbitrarily chosen for now
    timesteps = steps
    left_constant = 0
    right_constant = 0

    y_new = []

    for i in range(plots):
        y_new.append(y_avgs[i])

    for k in range(timesteps):
        for i in range(boxes):
            value = y_new[int(i*box_size)]

            # u_{t+1} = u_{t} + l_flux*dt - r_flux*dt

            if (i == 0):
                # l_flux = flux_function(left_constant, value)
                l_flux = godunov(left_constant, value)
            else:
                # l_flux = flux_function(y_new[int(i*box_size) - 1], value)
                l_flux = godunov(y_new[int((i-1)*box_size)], value)

            if (i >= boxes - 1):
                # r_flux = flux_function(value, right_constant)
                r_flux = godunov(value, right_constant) 
            else:
                # r_flux = flux_function(value, y_new[int(i*box_size) + 1])
                r_flux = godunov(value, y_new[int((i+1)*box_size)])

            new_val = value + l_flux * dt - r_flux * dt

            for j in range(int(box_size)):
                y_new[int(i*box_size + j)] = new_val
    
    return y_new

# %%
steps = 0
arr = flux_approx_method(150)

plt.plot(x, arr, color = 'navy') #, label = 'Approximation'
# plt.plot(x, y, color = 'orangered', label = 'True Initial Value')
plt.title(f'Approximation after {0.1 * steps}s')
plt.ylabel('Conserved Quantity')
plt.xlabel('Distance (m)')
plt.xlim(x[0], x[-1])
plt.ylim(-1.1, 1.1)
# plt.legend(frameon=False)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 steps = 0
# ----> 2 arr = flux_approx_method(150)
#       4 plt.plot(x, arr, color = 'navy') #, label = 'Approximation'
#       5 # plt.plot(x, y, color = 'orangered', label = 'True Initial Value')
#
# Cell In[16], line 30, in flux_approx_method(steps)
#      27     r_flux = godunov(value, right_constant)
#      28 else:
#      29     # r_flux = flux_function(value, y_new[int(i*box_size) + 1])
# ---> 30     r_flux = godunov(value, y_new[int((i+1)*box_size)])
#      32 new_val = value + l_flux * dt - r_flux * dt
#      34 for j in range(int(box_size)):
#
# IndexError: list index out of range

# %% [markdown]
# # Animation

# %%
fig, ax = plt.subplots()

u, = ax.plot(x, flux_approx_method(0), color = 'navy', label = 'Approximation')

def animate(i):
    u.set_ydata(flux_approx_method(i))  # update the data.
    return u,

ani = animation.FuncAnimation(fig, animate, interval=100, blit=True, save_count=200)

plt.plot(x, y, color = 'orangered', label = 'True Initial Value')
plt.title('Godunov Scheme Approximation Over Time (Advection Equation, Periodic)')
plt.ylabel('Y')
plt.xlabel('X')
plt.xlim(x[0], x[-1])
plt.legend(frameon=False, loc=3)
plt.grid()

# To save the animation, use
writergif = animation.PillowWriter(fps=30)
ani.save('sine_wave_advection_periodic.gif',writer=writergif)

plt.show()
